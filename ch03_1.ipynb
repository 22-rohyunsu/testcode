# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/opencv colab/img/gsy.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
Gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(Gray_img.shape)
plt.imshow(Gray_img, cmap='gray')
# Out:
# (1067, 800)

# %%
cv2_imshow(Gray_img)
# Out:
# <PIL.Image.Image image mode=L size=800x1067>

# %%
mimg = cv2.resize(Gray_img, dsize=(256 * 4, 256 * 4))
plt.imshow(mimg, cmap='gray')

# %%
cv2_imshow(mimg)
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>

# %%
for h in range(100, 150):
  for w in range(100, 150):
    Gray_img[h, w] = 0

cv2_imshow(Gray_img)
# Out:
# <PIL.Image.Image image mode=L size=800x1067>
